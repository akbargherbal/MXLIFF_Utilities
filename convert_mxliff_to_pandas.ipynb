# %%
import xmltodict
import pandas as pd
import regex as re
from datetime import datetime
import os

# %%
from difflib import SequenceMatcher

# %%
def read_mxliff_file(file_path):
    with open(file_path, encoding='utf-8') as xml_file:
        data_dict = xmltodict.parse(xml_file.read())
    return data_dict

# %%
def extract_data(data_dict):
    list_groups = data_dict['xliff']['file']['body']['group']
    data_for_pd = [(i['@id'], i['@m:para-id'], i['trans-unit']) for i in list_groups]
    df = pd.DataFrame(data_for_pd, columns=['p_id', 'para_id', 'trans_unit'])
    return df

# %%
def timestamp_to_human_readable(timestamp_ms):
    timestamp_ms = int(timestamp_ms)
    timestamp = timestamp_ms / 1000  # Convert from milliseconds to seconds
    human_readable_time = datetime.fromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
    return human_readable_time

# %%
input_file_path = 'Mark-ar-ar_bh-T.mxliff'

# %%
df = extract_data(read_mxliff_file(input_file_path))
df['SOURCE'] = df.trans_unit.apply(lambda x: x['source'])
df['TARGET'] = df.trans_unit.apply(lambda x: x['target'])
df['GROSS_SCORE'] = df.trans_unit.apply(lambda x: float(x['@m:gross-score']))
df['M_SCORE'] = df.trans_unit.apply(lambda x: float(x['@m:score']))
df['MODIFIED_AT'] = df.trans_unit.apply(lambda x: x['@m:modified-at'])
df['MODIFIED_AT'] = df['MODIFIED_AT'].apply(lambda x: timestamp_to_human_readable(x))
df['LOCKED'] = df.trans_unit.apply(lambda x: x['@m:locked'])
df['ALT_MATCH_QUALITY'] = df.trans_unit.apply(lambda x: round(float(x['alt-trans'][1]['@match-quality']), 2))
df['ALT_TARGET'] = df.trans_unit.apply(lambda x: x['alt-trans'][1]['target'])
df['CONFIRMED'] = df.trans_unit.apply(lambda x: x['@m:confirmed'])

# %%
test = df.sort_values(['MODIFIED_AT'], ascending=False).head(30)

# %%
for i in zip(test.SOURCE, test.TARGET):
    print(i[0])
    print(i[1])
    print('--------------')
# Out:
# \h الإنجيل كما دونه مرقس
# \h الإنجيل مثل ما كتبه مرقس
# --------------
# \v 17 فَإِنَّ هِيرُودُسَ هَذَا كَانَ قَدْ أَرْسَلَ وَقَبَضَ عَلَى يُوحَنَّا وَقَيَّدَهُ فِي السِّجْنِ.
# \v 17 لأن هِيرُودُسُ هذا كان طرش على يوحنا حق يجودونه ويجبسونه.
# --------------
# وَذلِكَ مِنْ أَجْلِ هِيرُودِيَّا الَّتِي تَزَوَّجَهَا هِيِرُودُسُ وَهِيَ زَوْجَةُ أَخِيهِ فِيلِبُّسَ.
# وهالشيء لأن هِيِرُودُسُ بغى يتزوج هِيرُودِيَّا وهي كات مَرْت أخوه فِيلِبُّسَ.
# --------------
# \s1 يسوع يطعم خمسة آلاف
# \s1 يسوع يْأَكِّلْ خمسة آلاف
# --------------
# فَأَخَذَ يَتَحَيَّنُ تَسْلِيمَهُ فِي فُرْصَةٍ مُنَاسِبَةٍ.
# فقام يفكر شلون يسلمه لما تجي الفرصة المناسبة.
# --------------
# \v 31 ثُمَّ غَادَرَ يَسُوعُ نَوَاحِي صُورَ وَعَادَ إِلَى بُحَيْرَةِ الْجَلِيلِ، مُرُوراً بِصَيْدَا وَعَبْرَ حُدُودِ الْمُدُنِ الْعَشْرِ.
# \v 31 بعدين طلع يسوع من نواحي صور ورجع إلى بحر الجليل، مار بصيدا وعبر حدود المداين العشر.
# --------------
# \v 1 ثُمَّ أَخَذَ يُعَلِّمُ ثَانِيَةً عِنْدَ شَاطِئِ الْبُحَيْرَةِ، وَقَدِ احْتَشَدَ حَوْلَهُ جَمْعٌ كَبِيرٌ، حَتَّى إِنَّهُ صَعِدَ إِلَى الْقَارِبِ وَجَلَسَ فِيهِ فَوْقَ الْمَاءِ، فِيمَا كَانَ الْجَمْعُ كُلُّهُ عَلَى شَاطِئِ الْبُحَيْرَةِ.
# \v 1 بعدين قام يعلم مرة ثانية عند ساحل البحر، واحتشد حوله جماعة كبيرة، حتى إنه صعد السفينة وقعد فيها وهو فوق الماي، والجماعة كلها على ساحل البحر.
# --------------
# \v 47 وَلَمَّا حَلَّ الْمَسَاءُ، كَانَ الْقَارِبُ فِي وَسَطِ الْبُحَيْرَةِ، وَيَسُوعُ وَحْدَهُ عَلَى الْبَرِّ.
# \v 47 ولما جا المسا، كانت السفينة في وسط البحر، ويسوع وحده على البر.
# --------------
# \v 48 وَإِذْ رَآهُمْ يَتَعَذَّبُونَ فِي التَّجْذِيفِ، لأَنَّ الرِّيحَ كَانَتْ مُعَاكِسَةً لَهُمْ، جَاءَ إِلَيْهِمْ مَاشِياً عَلَى مَاءِ الْبُحَيْرَةِ، نَحْوَ الرُّبْعِ الأَخِيرِ مِنَ اللَّيْلِ، وَكَادَ أَنْ يَتَجَاوَزَهُمْ.
# \v 48 ولما شافهم متعذبين في التجديف، لأن الريح كانت عكسهم، جا إليهم يمشي على ماي البحر، تقريبًا في الربع الأخير من الليل، ولو شوي تجاوزهم.
# --------------
# \v 7 فَانْسَحَبَ يَسُوعُ وَتَلامِيذُهُ نَحْوَ الْبُحَيْرَةِ.
# \v 7 فانسحب يسوع وتلاميذه ناحية البحر.
# --------------
# \v 13 وَخَرَجَ يَسُوعُ ثَانِيَةً إِلَى شَاطِئِ الْبُحَيْرَةِ، فَلَحِقَ بِهِ الْجَمْعُ كُلُّهُ.
# \v 13 وراح يسوع مرة ثانية إلى ساحل البحر، فلحقت به الجماعة كلها.
# --------------
# \v 16 وَفِيمَا كَانَ يَسُوعُ يَمْشِي عَلَى شَاطِئِ بُحَيْرَةِ الْجَلِيلِ، رَأَى سِمْعَانَ وَأَخَاهُ أَنْدَرَاوُسَ يُلْقِيَانِ الشَّبَكَةَ فِي الْبُحَيْرَةِ، فَقَدْ كَانَا صَيَّادَيْنِ.
# \v 16 ولما كان يسوع يمشي على ساحل بحر الجليل، شاف سمعان وأخوه أندراوس يرموا الشبك في البحر، لأنهم كانوا صيادين.
# --------------
# \s1 يسوع يشفي رجلاً أبرص
# \s1 يسوع يشفي رجال أبرص
# --------------
# \v 39 وَذَهَبَ يُبَشِّرُ فِي مَجَامِعِ الْيَهُودِ فِي مِنْطَقَةِ الْجَلِيلِ كُلِّهَا، وَيَطْرُدُ الشَّيَاطِينَ.
# \v 39 وراح يبشر في مجامع اليهود في منطقة الجليل كلها، ويطرد الشياطين.
# --------------
# فَلأَجْلِ هَذَا جِئْتُ.»
# هذا الشيء اللي جيت حقه.»
# --------------
# \v 38 فَقَالَ لَهُمْ: «لِنَذْهَبْ إِلَى مَكَانٍ آخَرَ فِي الْقُرَى الْمُجَاوِرَةِ لأُبَشِّرَ هُنَاكَ أَيْضاً.
# \v 38 فقال لهم: «خل نروح إلى مكان ثاني في القرى القريبة حتى أبشر هناك بعد،
# --------------
# \v 37 «إِنَّ الْجَمِيعَ يَطْلُبُونَكَ!»
# \v 37 «كل الناس يطلبونك!»
# --------------
# فَلَمَّا وَجَدُوهُ قَالُوا لَهُ:
# ولما حصلوه قالوا له:
# --------------
# \v 36 فَذَهَبَ سِمْعَانُ وَمَنْ مَعَهُ يَبْحَثُونَ عَنْهُ.
# \v 36 فراح سمعان واللي وياه يدوروا عنه.
# --------------
# \v 35 وَفِي الْيَوْمِ التَّالِي، نَهَضَ بَاكِراً قَبْلَ الْفَجْرِ، وَخَرَجَ إِلَى مَكَانٍ مُنْعَزِلٍ وَأَخَذَ يُصَلِّي هُنَاكَ.
# \v 35 وفي اليوم الثاني، قعد من غبشة قبل الفجر، وراح إلى مكان معزول وقام يصلي هناك.
# --------------
# \p
# \p
# --------------
# \v 32 وَعِنْدَ حُلُولِ الْمَسَاءِ، لَمَّا غَرَبَتِ الشَّمْسُ، أَحْضَرَ النَّاسُ إِلَيْهِ جَمِيعَ مَنْ كَانُوا مَرْضَى وَمَسْكُونِينَ بِالشَّيَاطِينِ،
# \v 32 ويوم جا الليل، لما غربت الشمس، جابوا له الناس كل اللي كانوا مرضى ومسكونين بالشياطين،
# --------------
# \s1 يسوع يصلي في مكان منعزل
# \s1 يسوع يصلي في مكان معزول
# --------------
# \v 34 فَشَفَى كَثِيرِينَ كَانُوا يُعَانُونَ مِنْ أَمْرَاضٍ مُخْتَلِفَةٍ، وَطَرَدَ شَيَاطِينَ كَثِيرَةً، وَلكِنَّهُ لَمْ يَسْمَحْ لِلشَّيَاطِينِ بِأَنْ يَتَكَلَّمُوا، لأَنَّهُمْ عَرَفُوا مَنْ هُوَ.
# \v 34 فشفى منهم ناس واجد فيهم أمراض متنوعة، وطرد منهم شياطين واجد، وما خلى للشياطين مجال للكلام، لأنهم عرفوا من هو.
# --------------
# \v 33 حَتَّى احْتَشَدَ أَهْلُ الْمَدِينَةِ كُلُّهُمْ عِنْدَ البَابِ.
# \v 33 إلى درجة إن أهل المدينة تجمعوا كلهم عند الباب.
# --------------
# \v 30 وَكَانَتْ حَمَاةُ سِمْعَانَ طَرِيحَةَ الْفِرَاشِ، تُعَانِي مِنَ الْحُمَّى.
# \v 30 وكانت حماة سمعان مريضة وممدة على السرير، صادتها الصخونة.
# --------------
# فَفِي الْحَالِ كَلَّمُوا يَسُوعَ بِشَأْنِهَا.
# وعلى طول كلموا يسوع عنها.
# --------------
# \v 31 فَاقْتَرَبَ إِلَيْهَا، وَأَمْسَكَ بِيَدِهَا وَأَنْهَضَهَا.
# \v 31 فقرب إليها، وجوَّد إيدينها وقوَّمها.
# --------------
# فَذَهَبَتْ عَنْهَا الْحُمَّى حَالاً، وَقَامَتْ تَخْدِمُهُمْ.
# فراحت عنها الصخونة على طول، وقامت تخدمهم.
# --------------
# \v 29 وَحَالَمَا غَادَرُوا الْمَجْمَعَ، دَخَلُوا بَيْتَ سِمْعَانَ وَأَنْدَرَاوُسَ، وَمَعَهُمْ يَعْقُوبُ وَيُوحَنَّا.
# \v 29 وبمجرد إنهم راحوا، دخلوا بيت سمعان وأندراوس، ومعهم يعقوب ويوحنا.
# --------------

# %%
set(''.join(df['SOURCE'])) - set(''.join(df['TARGET']))
# Out:
# {'ٌ', 'ٍ', '\u2006', '–'}

# %%
df[df['TARGET'].apply(lambda x: 'ـ' in x)]
# Out:
#     p_id para_id                                         trans_unit  \
# 683  683     560  {'@id': '0rgV1fdxzRMUsfOA1_dc5:683', '@xml:spa...
#
#                                                 SOURCE  \
# 683  وَبَيْنَمَا كَانَ خَارِجاً مِنْ أَرِيحَا، وَمَ...
#
#                                                 TARGET  GROSS_SCORE  M_SCORE  \
# 683  ولما كان طالع من أريحا، ويا تلاميذه وجماعة كبي...         0.99     0.99
#
#              MODIFIED_AT LOCKED  ALT_MATCH_QUALITY  \
# 683  2023-08-04 23:43:27  false               0.99
#
#                                             ALT_TARGET CONFIRMED
# 683  ولما كان طالع من أريحا، ويا تلاميذه وجماعة كبي...         1

# %%
df['SOURCE'].iloc[683]
# Out:
# 'وَبَيْنَمَا كَانَ خَارِجاً مِنْ أَرِيحَا، وَمَعَهُ تَلامِيذُهُ وَجَمْعٌ كَبِيرٌ، كَانَ بَارْتِيمَاوُسُ الأَعْمَى\u2006–\u2006ابْنُ تِيمَاوُسَ، جَالِساً عَلَى جَانِبِ الطَّرِيقِ يَسْتَعْطِي.'

# %%
diacritics = '''
َ
ً
ُ
ٌ
ْ
ٍ
ْ
ّ
'''.strip().split()
diacritics = set(diacritics)

# %%
diacritics
# Out:
# {'ً', 'ٌ', 'ٍ', 'َ', 'ُ', 'ّ', 'ْ'}

# %%
pat_diacritics = ''.join(diacritics)
pat_diacritics = fr"[{pat_diacritics}]"

# %%
pat_diacritics =  re.compile(pat_diacritics)

# %%
df['TARGET'] = df['TARGET'].apply(lambda x: re.sub(pat_diacritics, '', x))
df['SOURCE'] = df['SOURCE'].apply(lambda x: re.sub(pat_diacritics, '', x))

# %%
# Utility function to compute similarity
def similar(str1, str2):
    return SequenceMatcher(None, str1, str2).ratio()

# %%
df['SIM_SCORE'] = df.apply(lambda x: similar(x['SOURCE'], x['TARGET']), axis=1)

# %%
test = df.sort_values(['SIM_SCORE'])

# %%
for i in zip(test['SOURCE'].head(30), test['TARGET'].head(30), test['SIM_SCORE'].head(30)):
    print(i[0])
    print(i[1])
    print(i[2])
    print('----------')
# Out:
# إِنهم سيهابون ابنِي!
# أكيد راح يخافوا ولدي!
# 0.34146341463414637
# ----------
# \ip وينتهي هذا الإنجيل إلى الحديث عن نهاية الزمان وما سيحدث عند رجوع المسيح ثم يسرد الأحداث المتعلقة بآلام المسيح وموته وقيامته وصعوده إلى المجد، ويؤكد على مساندة المسيح لتلاميذه فيما هم ينشرون البشارة في العالم أجمع.
# \ip وينتهي هذا الإنجيل عند الكلام عن نهاية الزمان وويش اللي راح يصير لما يرجع المسيح ويحچي الأحداث اللي تخص آلام المسيح وموته وقيامته وصعوده إلى المجد، ويأكد على مساندة المسيح لتلاميذه وهم ينشروا البشارة في العالم كله.
# 0.3448275862068966
# ----------
# ثم صرفهم،
# وبعدين مشاهم،
# 0.36363636363636365
# ----------
# وأيضا:
# وبعد:
# 0.36363636363636365
# ----------
# \v 26 وقد عانتِ الكثِير مِن الألمِ على أيدِي أطِباء كثِيرِين، وأنفقت فِي سبِيلِ عِلاجِها كل ما تملِك، فلم تجنِ أية فائِدة، بل بِالأحرى ازدادت حالتها سوءا.
# \v 26 وقاست واجد من الألم وشافت أطباء واجد، وصرفت كل الفلوس اللي تملكها على العلاج، وما حصلت فايدة، بالعكس زادت حالتها بلى.
# 0.37545126353790614
# ----------
# فلأجلِ هذا جِئت.»
# هذا الشيء اللي جيت حقه.»
# 0.3902439024390244
# ----------
# \v 5 ثم أرسل آخر أيضا فقتلوه.
# \v 5 وبعدين رد طرش واحد ثاني وقتلوه.
# 0.4
# ----------
# ثم أرسل آخرِين كثِيرِين، فضربوا بعضا وقتلوا بعضا.
# وبعدين طرش ناس واجد، بعضهم ضربوهم وبعضهم قتلوهم.
# 0.4329896907216495
# ----------
# إِنه يدعوك!»
# قوم يبغاك!»
# 0.43478260869565216
# ----------
# \v 37 وذهِلوا جِدا، قائِلِين: «ما أروع كل ما يفعل.
# \v 37 واندهشوا واجد، وقالوا: «وش هالعجب العجاب كل اللي يسويه.
# 0.45045045045045046
# ----------
# فليس مِن الصوابِ أن يؤخذ خبز البنِين ويطرح لِلكِلابِ».
# لأن مو عدل إن ناخذ خبز الأولاد ونعطيه الچلاب».
# 0.46
# ----------
# \v 31 وهناك أولون كثِيرون يصِيرون آخِرِين، والآخِرون يصِيرون أولِين!»
# \v 31 وهناك ناس كثيرين هم في الأول يصيروا في الأخير، وناس في الأخير يصيروا في الأول!»
# 0.4675324675324675
# ----------
# \v 20 فقد كان هنالِك سبعة إِخوة، اتخذ أولهم زوجة ثم مات دون أن يخلِف نسلا،
# \v 20 لأن كان في سبعة إخوة، تزوج واحد منهم ومات وما جاب أولاد،
# 0.47058823529411764
# ----------
# \v 43 وأما أنتم فلا يكن ذلِك بينكم، وإِنما أي من أراد أن يصِير عظِيما بينكم، فليكن لكم خادِما،
# \v 43 بينما أنتوا ما يصير هذا بينكم، لكن اللي يبغى يصير عظيم بينكم، لازم يكون خادم،
# 0.4745762711864407
# ----------
# فأبعِد عنِي هذِهِ الكأس، ولكِن لِيكن لا ما أرِيد أنا، بل ما ترِيد أنت!»
# فباعد عني هذي الكاس، وخل يصير مو اللي أبغاه، لكن اللي أنت تبغاه!»
# 0.4852941176470588
# ----------
# لن يعطى هذا الجِيل آية!»
# هالجيل ما راح ينعطى آية!»
# 0.4897959183673469
# ----------
# \v 6 فإِن كثِيرِين سيأتون بِاسمِي قائِلِين، إِنِي أنا هو ويضلِلون كثِيرِين.
# \v 6 لأن ناس واجد راح يجوا باسمي ويقولوا، إنهم أنا ويضلوا ناس واجد.
# 0.49295774647887325
# ----------
# إِنه حيث يبشر بِالإِنجِيلِ فِي العالمِ أجمع، يحدث أيضا بِما عمِلته هذِهِ المرأة، إِحياء لِذِكرِها!»
# وفي كل مكان في العالم يصير فيه تبشير بالإنجيل، يصير مثل اللي سوته هذي المرة، إحياء لذكرها!»
# 0.49473684210526314
# ----------
# \v 7 «لِماذا يتكلم هذا الرجل هكذا؟ إِنه يتكلم كفرا!
# \v 7 «ليش يتكلم هالرجال چذا؟ هذا يتكلم بالكفر!
# 0.4948453608247423
# ----------
# وإِذ تفكر بِذلِك أخذ يبكِي.
# ويوم فكر بهذا الشيء قام يصيح.
# 0.5
# ----------
# ومِن بعدِهِم جمِيعا، ماتتِ المرأة أيضا.
# وبعدين ماتت المرة عقبهم كلهم بعد.
# 0.5
# ----------
# فقد كان القادِمون والذاهِبون كثِيرِين حتى لم يدعوا لهم فرصة لِلأكلِ.
# لأن الرايحين والجايين كانوا واجد وما تركوا ليهم فرصة حتى للأكل.
# 0.5038167938931297
# ----------
# وذلِك مِن أجلِ هِيرودِيا التِي تزوجها هِيِرودس وهِي زوجة أخِيهِ فِيلِبس.
# وهالشيء لأن هِيِرودس بغى يتزوج هِيرودِيا وهي كات مرت أخوه فِيلِبس.
# 0.5072463768115942
# ----------
# \v 21 ثم سنحتِ الفرصة عِندما أقام هِيرودس بِمناسبةِ ذِكرى مولِدِهِ ولِيمة لِعظمائِهِ وقادةِ الألوفِ وأعيانِ مِنطقةِ الجلِيلِ.
# \v 21 بعدين جت فرصة يوم سوى هِيرودس عزيمة بمناسبة عيد ميلاده ودعا كبار المسؤولين ورؤساء الألوف وكبار الناس في منطقة الجليل.
# 0.5161290322580645
# ----------
# وما إِن رآه، حتى ارتمى عِند قدميهِ،
# وما شافه، إلا ورمى روحه عند رجوله،
# 0.5217391304347826
# ----------
# فانتحى بِهِ بطرس جانِبا وأخذ يوبِخه.
# فأخذه بطرس على جنب وعصب عليه.
# 0.5230769230769231
# ----------
# \v 37 فهبت عاصِفة رِيح شدِيدة، وأخذتِ الأمواج تضرِب القارِب حتى كاد يمتلِىء ماء.
# \v 37 فهبت ريح قوية، والامواج قامت تضرب السفينة لدرجة إن الماي ترسها.
# 0.5234899328859061
# ----------
# \v 46 فألقوا القبض عليهِ.
# \v 46 فجودوه.
# 0.5263157894736842
# ----------
# \v 9 بل ينتعِلوا حِذاء ويلبسوا رِداء واحِدا.
# \v 9 يلبسوا نعال واحد وردا واحد.
# 0.5263157894736842
# ----------
# وكان معه أيضا قوارِب أخرى.
# وكان معاه بعد سفينات ثانية.
# 0.5283018867924528
# ----------

# %%
test['LEN_DIFF'] = test.apply(lambda x: abs(len(x['SOURCE'].split())  - len(x['TARGET'].split())), axis=1)

# %%
test['LEN_DIFF'].describe()
# Out:
# count    1126.000000
# mean        0.582593
# std         0.879302
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         7.000000
# Name: LEN_DIFF, dtype: float64

# %%
# Out:
#       p_id para_id                                         trans_unit  \
# 656    656     538  {'@id': '0rgV1fdxzRMUsfOA1_dc5:656', '@xml:spa...
# 1049  1049     836  {'@id': '0rgV1fdxzRMUsfOA1_dc5:1049', '@xml:sp...
# 781    781     629  {'@id': '0rgV1fdxzRMUsfOA1_dc5:781', '@xml:spa...
# 222    222     185  {'@id': '0rgV1fdxzRMUsfOA1_dc5:222', '@xml:spa...
# 379    379     314  {'@id': '0rgV1fdxzRMUsfOA1_dc5:379', '@xml:spa...
# 49      49      43  {'@id': '0rgV1fdxzRMUsfOA1_dc5:49', '@xml:spac...
#
#                                                  SOURCE  \
# 656   \v 31 وهناك أولون كثِيرون يصِيرون آخِرِين، وال...
# 1049  \v 20 وبعدما أوسعوه سخرِية، نزعوا رِداء الأرجو...
# 781   \v 15 ولكِنه إِذ علِم نِفاقهم قال لهم: «لِماذا...
# 222   \v 22 فليس مخفِي إِلا ويكشف، وما كتِم شيء إِلا...
# 379   \v 41 ثم أخذ يسوع الأرغِفة الخمسة والسمكتينِ، ...
# 49    \v 22 فذهِل الحاضِرون مِن تعلِيمِهِ، لأنه كان ...
#
#                                                  TARGET  GROSS_SCORE  M_SCORE  \
# 656   \v 31 وهناك ناس كثيرين هم في الأول يصيروا في ا...         0.96     0.96
# 1049  \v 20 وبعد ما كثروا من الاستهزاء فيه، شالوا عن...         0.97     0.97
# 781   \v 15 ولكن لأنه كان يعرف إن هذا نفاق منهم فقال...         0.00     0.00
# 222   \v 22 فما في شيء مخفي إلا وراح ينكشف، وما في ش...         0.00     0.00
# 379   \v 41 بعدين أخذ يسوع أقراص الخبز الخمسة والسمچ...         0.98     0.98
# 49    \v 22 وانهدش الحاضرين من تعليمه، لأنه كان يعلم...         0.97     0.97
#
#               MODIFIED_AT LOCKED  ALT_MATCH_QUALITY  \
# 656   2023-08-04 23:43:21  false               0.96
# 1049  2023-08-04 23:44:49  false               0.97
# 781   2023-08-04 23:43:48  false               0.56
# 222   2023-08-04 23:41:37  false               0.00
# 379   2023-08-04 23:42:15  false               0.98
# 49    2023-08-04 23:45:17  false               0.97
#
#                                              ALT_TARGET CONFIRMED  SIM_SCORE  \
# 656   31 وهناك ناس كثيرين هم في الأول يصيروا في الأخ...         1   0.467532
# 1049  20 وبعد ما كثروا من الاستهزاء فيه، شالوا عنه ث...         1   0.600000
# 781   هل يجوز لينا ندفع الجزية لقيصر أو لا؟ ندفعها أ...         1   0.633333
# 222                                                None         1   0.661290
# 379   41 بعدين أخذ يسوع أقراص الخبز الخمسة والسمچتين...         1   0.737179
# 49    22 وانهدش الحاضرين من تعليمه، لأنه كان يعلمهم ...         1   0.748538
#
#       LEN_DIFF
# 656          7
# 1049         5
# 781          5
# 222          5
# 379          5
# 49           5
